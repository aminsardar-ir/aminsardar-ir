# %% [markdown]
# <a href="https://colab.research.google.com/github/aminsardar-ir/aminsardar-ir/blob/main/GraphModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# load model

# %%
from google.colab import drive
root = '/content/gdrive/'
drive.mount( root )
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
from keras.models import load_model
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
import numpy as np

model = tf.keras.models.load_model('/content/gdrive/MyDrive/NewP3te/opmodels-29.h5')

# %%
# Convert Keras model to ConcreteFunction
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype))

# %%
# Get frozen graph def
frozen_func = convert_variables_to_constants_v2(full_model)
frozen_func.graph.as_graph_def()

# %%
layers = [op.name for op in frozen_func.graph.get_operations()]
print("-" * 60)
print("Frozen model layers: ")
for layer in layers:
    print(layer)
print("-" * 60)
print("Frozen model inputs: ")
print(frozen_func.inputs)
print("Frozen model outputs: ")
print(frozen_func.outputs)
# Out:
# ------------------------------------------------------------
# Frozen model layers:
# x
# model/conv1_pad/Pad/paddings
# model/conv1_pad/Pad
# model/conv1_conv/Conv2D/ReadVariableOp/resource
# model/conv1_conv/Conv2D/ReadVariableOp
# model/conv1_conv/Conv2D
# model/conv1_conv/BiasAdd/ReadVariableOp/resource
# model/conv1_conv/BiasAdd/ReadVariableOp
# model/conv1_conv/BiasAdd
# model/conv1_bn/ReadVariableOp/resource
# model/conv1_bn/ReadVariableOp
# model/conv1_bn/ReadVariableOp_1/resource
# model/conv1_bn/ReadVariableOp_1
# model/conv1_bn/FusedBatchNormV3/ReadVariableOp/resource
# model/conv1_bn/FusedBatchNormV3/ReadVariableOp
# model/conv1_bn/FusedBatchNormV3/ReadVariableOp_1/resource
# model/conv1_bn/FusedBatchNormV3/ReadVariableOp_1
# model/conv1_bn/FusedBatchNormV3
# model/conv1_relu/Relu
# model/pool1_pad/Pad/paddings
# model/pool1_pad/Pad
# model/pool1_pool/MaxPool
# model/conv2_block1_0_conv/Conv2D/ReadVariableOp/resource
# model/conv2_block1_0_conv/Conv2D/ReadVariableOp
# ...

# %%
tf.io.write_graph(graph_or_graph_def=frozen_func.graph,
                  logdir='/content/gdrive/MyDrive/NewP3te',
                  name='frozenModel.pb',
                  as_text=False)
# Out:
# '/content/gdrive/MyDrive/NewP3te/frozenModel.pb'
